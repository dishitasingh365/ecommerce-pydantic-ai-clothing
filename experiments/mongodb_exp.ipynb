# %%
print("okay")
# Out:
# okay

# %%
import os
from dotenv import load_dotenv
from pymongo import MongoClient

# %%
from dotenv import load_dotenv
import os
from pymongo import MongoClient

load_dotenv()

print(os.getenv("MONGO_URI"))

client = MongoClient(os.getenv("MONGO_URI"))

print("Connected!")
# Out:
# mongodb+srv://dishitasingh_db_user:Dishita%40052211@ecom-pydantic.mrtvqbn.mongodb.net/?appName=ecom-pydantic
# Connected!

# %%
db = client["test_ecom_db"]
collection = db["products"]
print("connected to mongodb")
# Out:
# connected to mongodb

# %%
product = {
    "name": "Men Casual Shirt",
    "price": 999,
    "category": "men"
}

collection.insert_one(product)
# Out:
# InsertOneResult(ObjectId('6a0cddcd2c62a03863a079f2'), acknowledged=True)

# %%
products = [
    {"name": "Jeans", "price": 1499, "category": "men"},
    
    {"name": "Kurti", "price": 999, "category": "women"},
    
    {"name": "Kids Jacket", "price": 1299, "category": "kids"}
]

collection.insert_many(products)

print("Multiple Products Inserted ✅")
# Out:
# Multiple Products Inserted ✅

# %%
# 🔹 CELL 6 - View All Products

all_products = collection.find()

for p in all_products:
    print(p)
# Out:
# {'_id': ObjectId('6a0cddcd2c62a03863a079f2'), 'name': 'Men Casual Shirt', 'price': 999, 'category': 'men'}
# {'_id': ObjectId('6a0cdf3a2c62a03863a079f3'), 'name': 'Jeans', 'price': 1499, 'category': 'men'}
# {'_id': ObjectId('6a0cdf3a2c62a03863a079f4'), 'name': 'Kurti', 'price': 999, 'category': 'women'}
# {'_id': ObjectId('6a0cdf3a2c62a03863a079f5'), 'name': 'Kids Jacket', 'price': 1299, 'category': 'kids'}

# %%
product = collection.find_one({"name": "Kurti"})

print(product)
# Out:
# {'_id': ObjectId('6a0cdf3a2c62a03863a079f4'), 'name': 'Kurti', 'price': 999, 'category': 'women'}

# %%
men_products = collection.find({"category": "men"})

for p in men_products:
    print(p)
# Out:
# {'_id': ObjectId('6a0cddcd2c62a03863a079f2'), 'name': 'Men Casual Shirt', 'price': 999, 'category': 'men'}
# {'_id': ObjectId('6a0cdf3a2c62a03863a079f3'), 'name': 'Jeans', 'price': 1499, 'category': 'men'}
