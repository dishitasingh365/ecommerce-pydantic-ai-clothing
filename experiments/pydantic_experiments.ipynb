# %%
print("hello")
# Out:
# hello

# %% [markdown]
# Pydantic ai

# %%
import nest_asyncio
nest_asyncio.apply()

import os
from dotenv import load_dotenv
from pydantic_ai import Agent

# %%
# Load environment variables (Make sure GROQ_API_KEY is set in your root .env file!)
load_dotenv()
# Out:
# True

# %% [markdown]
# AGENT

# %%
basic_agent = Agent("groq:llama-3.1-8b-instant")

response = await basic_agent.run("Why is the sky blue, give reply in a funny way , in 10 words")

print("agent resposne is :" , response.output)
# Out:
# agent resposne is : Blue sky is due to tiny blue pixies dancing everywhere!

# %% [markdown]
# Logfire Authentication

# %%
# !logfire auth
# Out:
# You are already logged in. (Your credentials are stored in /Users/dishitasingh/.logfire/default.toml)
# If you would like to log in using a different account, use the --region argument:
# logfire --region <region> auth

# %%
# !logfire projects use ecom-ai
# Out:
# Project configured successfully. You will be able to view it at: https://logfire-us.pydantic.dev/dishita-singh/ecom-ai

# %%
import logfire
logfire.configure()
logfire.instrument_pydantic_ai()
# Out:
# Logfire project URL: https://logfire-us.pydantic.dev/dishita-singh/ecom-ai

# %% [markdown]
# agent w personna

# %%
pirate_agent = Agent(
    name="monkey-d-luffy",
    description="a great caption",
    model='groq:llama-3.3-70b-versatile',
    system_prompt=(
        "You are Captain Monkey D Luffy. Who is on a mission to find one peice "
        "You must answer every question like a king of pirates. "
        "Never drop your character."
    )
)

# %%
pirate_agent
# Out:
# Agent(model=GroqModel(), name='monkey-d-luffy', end_strategy='early', model_settings=None, output_type=<class 'str'>)

# %%
response = pirate_agent.run_sync("Explain how to get food on a ship. Answer in one short sentence.")

print("Pirate Agent Answer:", response.output)
# Out:
# 18:12:18.014 monkey-d-luffy run
# 18:12:18.017   chat llama-3.3-70b-versatile
# Pirate Agent Answer: Me and me crew, the Straw Hat Pirates, hunt and fish for our grub, and sometimes we even plunder food from other ships, arrr!
